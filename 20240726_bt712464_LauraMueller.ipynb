# %% [markdown]
# <a href="https://colab.research.google.com/github/LauraBMueller/LauraBMueller/blob/main/20240726_bt712464_LauraMueller.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparing the Data Analysis

# %%
#install necessary frameworks and libraries
# !pip install pandas
import pandas as pd

# !pip install matplotlib
import matplotlib.pyplot as plt

# !pip install numpy
import numpy as np

# !pip install seaborn
import seaborn as sns

# !pip install scipy
import scipy as sp

# %%
#upload datasets from eLearning
# !wget https://myfiles.uni-bayreuth.de/filr/public-link/file-download/043490 a38f2d6c72018fa73a25c26527/88424/490190348486392191/covidICU_export.zip
# !wget https://myfiles.uni-bayreuth.de/filr/public-link/file-download/043490 a38f2d6c72018fa73ab997652b/88425/1527977501430016014/CDC_Mort_export.zip
# Out:
# --2024-05-27 08:13:08--  https://myfiles.uni-bayreuth.de/filr/public-link/file-download/043490
# Resolving myfiles.uni-bayreuth.de (myfiles.uni-bayreuth.de)... 132.180.16.239
# Connecting to myfiles.uni-bayreuth.de (myfiles.uni-bayreuth.de)|132.180.16.239|:443... connected.
# HTTP request sent, awaiting response... 404
# 2024-05-27 08:13:08 ERROR 404: (no description).
#
# --2024-05-27 08:13:08--  http://a38f2d6c72018fa73a25c26527/88424/490190348486392191/covidICU_export.zip
# Resolving a38f2d6c72018fa73a25c26527 (a38f2d6c72018fa73a25c26527)... failed: Name or service not known.
# wget: unable to resolve host address ‘a38f2d6c72018fa73a25c26527’
# --2024-05-27 08:13:08--  https://myfiles.uni-bayreuth.de/filr/public-link/file-download/043490
# Resolving myfiles.uni-bayreuth.de (myfiles.uni-bayreuth.de)... 132.180.16.239
# Connecting to myfiles.uni-bayreuth.de (myfiles.uni-bayreuth.de)|132.180.16.239|:443... connected.
# HTTP request sent, awaiting response... 404
# ...

# %% [markdown]
# # ***Covid ICU Dataset Analysis***

# %% [markdown]
# ## General Overview

# %%
crp = pd.read_csv('/content/drive/MyDrive/CovidICU/CRP.csv')
crp = pd.DataFrame(crp)
crp.head()

#c-reactive protein test checks for inflammation in the body. Inflammation can be caused by infection, injury, or chronic disease.
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0              330.0              353.0               376.0
# 1              136.0              154.5               173.0
# 2              147.0              147.0               147.0
# 3              305.0              305.0               305.0
# 4              163.0              163.0               163.0
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0               379.0              382.0              371.0
# 1               192.5              212.0              226.0
# 2               225.0              303.0              303.5
# 3               305.0              305.0              244.5
# 4               163.0              163.0              163.0
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0               360.0               386.5              413.0
# 1               240.0               233.5              227.0
# ...

# %%
hco3 = pd.read_csv('/content/drive/MyDrive/CovidICU/HCO^-3.csv')
hco3 = pd.DataFrame(hco3)
hco3.head()

#bicarbonate testing is part of an electrolysis panel to identify or monitor electrolyte or pH imbalance and to screen for ketosis or acidosis
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0          22.000000          22.000000                28.3
# 1          28.973109          24.500000                23.7
# 2          23.100000          24.600000                28.1
# 3          29.721820          30.993431                21.3
# 4          22.000000          24.000000                23.0
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0                29.8               28.7               29.7
# 1                24.8               29.9               29.3
# 2                26.0               23.5               28.9
# 3                20.0               21.0               20.4
# 4                25.0               24.0               25.0
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0                31.4                32.9               29.7
# 1                28.1                30.0               29.5
# ...

# %%
lac = pd.read_csv('/content/drive/MyDrive/CovidICU/Lactate.csv')
lac = pd.DataFrame(lac)
lac.head()

#The lactate blood test is primarily ordered to help determine if someone has lactic acidosis, a level of lactate that is high enough to disrupt a person's acid-base (pH) balance. Lactic acidosis is most commonly caused by an inadequate amount of oxygen in cells and tissues (hypoxia)
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0           2.000000           1.800000                 1.1
# 1           0.944982           0.700000                 0.7
# 2           1.000000           1.100000                 0.9
# 3           1.419736           1.531753                 1.1
# 4           1.800000           1.500000                 1.6
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0                 1.4                1.7                1.4
# 1                 0.7                1.3                0.6
# 2                 1.2                1.1                1.2
# 3                 1.0                1.1                1.0
# 4                 1.9                1.5                1.7
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0                 1.9                 1.2                2.3
# 1                 0.8                 0.8                1.3
# ...

# %%
spo2 = pd.read_csv('/content/drive/MyDrive/CovidICU/Oxygen saturation.csv')
spo2 = pd.DataFrame(spo2)
spo2.head()

#Measured with a pulsoximeter, typically attached to finger or earlobe. Normal oxygen saturation levels range between 94%-99%. When SPo2 levels fall below 93% it is a sign that oxygen therapy is required.
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0               93.0               94.0                95.0
# 1               97.0               95.0                93.0
# 2               96.0               95.5                95.0
# 3               94.0               94.0                92.0
# 4               95.0               95.0                97.0
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0                94.5               94.0               95.0
# 1                93.5               94.0               94.0
# 2                95.5               96.0               94.5
# 3                91.0               91.0               91.0
# 4                95.0               97.0               93.0
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0                96.0                95.5               95.0
# 1                94.0                92.5               91.0
# ...

# %%
pfr = pd.read_csv('/content/drive/MyDrive/CovidICU/P-F Ratio.csv')
pfr = pd.DataFrame(pfr)
pfr.head()

#PaO2/FiO2 (=P/F) ratio is the ratio of arterial oxygen partial pressure (PaO2 in mmHg) to fractional inspired oxygen. A P/F Ratio less than 300 indicates acute respiratory failure.
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0              13.11          16.055000                19.0
# 1              13.27          18.535000                23.8
# 2              18.70          24.350000                30.0
# 3              12.70          12.700000                12.7
# 4              13.33          22.666667                16.6
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0           18.915000             18.830          18.505000
# 1           19.545000             15.290          13.957500
# 2           22.737500             15.475          16.275000
# 3           17.142857             13.940          20.545455
# 4           17.818182             23.550          28.571429
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0              18.180           16.680000          15.180000
# 1              12.625           11.982500          11.340000
# ...

# %%
paco2 = pd.read_csv('/content/drive/MyDrive/CovidICU/PaCO_2.csv')
paco2 = pd.DataFrame(paco2)
paco2.head()

#An elevated PaCO2 reflects alveolar hypoventilation, whereas a decreased PaCO2 reflects alveolar hyperventilation. Acute changes in PaCO2 will alter the pH. As a general rule, a low pH with a high PaCO2 suggests a respiratory acidosis, while a low pH with a low PaCO2 suggests a metabolic acidosis
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0           6.640000           5.650000                9.29
# 1           6.828975           4.870000                5.66
# 2           4.640000           5.340000                6.24
# 3           7.092268           6.967476                6.90
# 4           4.300000           6.200000                4.70
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0                7.53               6.55               7.20
# 1                6.34               6.41               6.45
# 2                6.75               5.15               6.19
# 3                9.30               6.20               7.50
# 4                7.20               6.60               6.00
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0                8.60                8.19               6.82
# 1                5.94                6.16               5.51
# ...

# %%
ppress = pd.read_csv('/content/drive/MyDrive/CovidICU/Peak pressure.csv')
ppress = pd.DataFrame(ppress)
ppress.head()

#Peak pressure is the pressure achieved during inspiration when the air is being pushed into the lungs and is a measure of airway resistance.
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0          30.000000               30.0                30.0
# 1          21.000000               20.0                19.0
# 2          24.000000               25.0                26.0
# 3          27.000000               27.0                27.0
# 4          25.678656               25.0                26.0
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0                29.0               28.0          28.000000
# 1                18.0               17.0          26.240354
# 2                27.0               28.0          28.000000
# 3                31.0               32.0          27.000000
# 4                24.0               27.0          26.000000
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0           28.000000           30.000000          32.000000
# 1           25.963185           27.353567          24.795156
# ...

# %%
ph = pd.read_csv('/content/drive/MyDrive/CovidICU/pH.csv')
ph = pd.DataFrame(ph)
ph.head()

#In the absence of pathological states, the pH of the human body ranges between 7.35 to 7.45, with the average at 7.40. Deviations indicate acidosis or
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0           7.290000           7.310000               7.270
# 1           7.325736           7.420000               7.369
# 2           7.410000           7.400000               7.380
# 3           7.352736           7.369006               7.270
# 4           7.430000           7.360000               7.430
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0               7.330              7.360              7.340
# 1               7.357              7.400              7.390
# 2               7.336              7.396              7.003
# 3               7.170              7.290              7.220
# 4               7.330              7.350              7.390
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0               7.240                7.32              7.490
# 1               7.425                7.43              7.462
# ...

# %%
plat = pd.read_csv('/content/drive/MyDrive/CovidICU/Platelet Count.csv')
plat = pd.DataFrame(plat)
plat.head()

#Thrombocytopenia is a frequent finding in intensive care unit especially among adults and medical ICU patients. Thrombocytopenia is defined as a platelet count less than 100×109/l in ICU setting.
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0              416.0              402.0               388.0
# 1              213.0              221.5               230.0
# 2              281.0              286.0               291.0
# 3              271.0              279.0               287.0
# 4              245.0              231.0               217.0
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0               406.5              425.0              402.5
# 1               228.0              226.0              246.0
# 2               296.5              302.0              343.0
# 3               328.0              369.0              364.0
# 4               223.0              229.0              210.5
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0               380.0               358.5              337.0
# 1               266.0               280.0              294.0
# ...

# %%
ventr = pd.read_csv('/content/drive/MyDrive/CovidICU/Ventilatory Ratio.csv')
ventr = pd.DataFrame(ventr)
ventr.head()

#The ventilatory ratio is a simple bedside index that can be calculated using routinely measured respiratory variables and is a measure of impaired ventilation. Ventilatory ratio is defined as [minute ventilation (ml/min) × PaCO2 (mm Hg)]/(predicted body weight × 100 × 37.5).
# Out:
#    first_day_morning  first_day_evening  second_day_morning  \
# 0           1.561171        3785.950138            2.450990
# 1        2740.564692        2740.564692            1.761572
# 2           1.053437        2717.071955            1.675973
# 3       -6021.531361       -6021.531361            2.081243
# 4        2892.219478        2892.219478          249.066886
#
#    second_day_evening  third_day_morning  third_day_evening  \
# 0         4506.539324           1.902741        -706.469119
# 1        -3634.096544           1.778385         658.647328
# 2         6278.644428           1.400128        2213.429707
# 3         4780.903740           1.942828       -1705.544273
# 4        -2394.085705       -1767.567315       -1141.048926
#
#    fourth_day_morning  fourth_day_evening  fifth_day_morning  \
# 0            2.439767        -4833.834379           2.305296
# 1         3560.456647         6462.265967        5895.255099
# ...

# %%
outcome = pd.read_csv('/content/drive/MyDrive/CovidICU/outcome.csv')
outcome = pd.DataFrame(outcome)
outcome.head()

#Patient Outcomes 7 days post admission
# Out:
#          outcome
# 0      Improving
# 1  Deteriorating
# 2  Deteriorating
# 3  Deteriorating
# 4  Deteriorating

# %% [markdown]
# ## Preprocessing

# %%
#screen crp for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for crp:')
print(crp.apply(num_missing, axis=0))
# Out:
# Missing values per columns for crp:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen hco3 for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for hco3:')
print(hco3.apply(num_missing, axis=0))
# Out:
# Missing values per columns for hco3:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen lac for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for lac:')
print(lac.apply(num_missing, axis=0))
# Out:
# Missing values per columns for lac:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen spo2 for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for spo2:')
print(spo2.apply(num_missing, axis=0))
# Out:
# Missing values per columns for spo2:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen pfr for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for pfr:')
print(pfr.apply(num_missing, axis=0))
# Out:
# Missing values per columns for pfr:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen paco2 for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for paco2:')
print(paco2.apply(num_missing, axis=0))
# Out:
# Missing values per columns for paco2:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen ppress for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for ppress:')
print(ppress.apply(num_missing, axis=0))
# Out:
# Missing values per columns for ppress:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen ph for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for ph:')
print(ph.apply(num_missing, axis=0))
# Out:
# Missing values per columns for ph:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen plat for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for plat:')
print(plat.apply(num_missing, axis=0))
# Out:
# Missing values per columns for plat:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen ventr for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for ventr:')
print(ventr.apply(num_missing, axis=0))
# Out:
# Missing values per columns for ventr:
# first_day_morning      0
# first_day_evening      0
# second_day_morning     0
# second_day_evening     0
# third_day_morning      0
# third_day_evening      0
# fourth_day_morning     0
# fourth_day_evening     0
# fifth_day_morning      0
# fifth_day_evening      0
# sixth_day_morning      0
# sixth_day_evening      0
# seventh_day_morning    0
# seventh_day_evening    0
# dtype: int64

# %%
#screen outcome for missing values
def num_missing(x):
  return sum(x.isnull())
print ('Missing values per columns for outcome:')
print(outcome.apply(num_missing, axis=0))
# Out:
# Missing values per columns for outcome:
# outcome    0
# dtype: int64

# %% [markdown]
# ## Descriptive Statistics

# %%
#Descriptives for crp
df = pd.DataFrame(crp)
print('Descriptives crp')
print(df.describe())
print('Medians crp')
print(df.median())
# Out:
# Descriptives crp
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean          234.216378         241.425003          248.633629
# std           110.408833         108.864194          111.971527
# min             1.800000           3.050000            4.300000
# 25%           151.325000         160.000000          164.250000
# 50%           231.000000         240.250000          248.333333
# 75%           311.925000         313.750000          324.950000
# max           691.000000         691.000000          691.000000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean           258.989430         269.345231         269.300463
# std            106.512926         114.685630         113.432756
# min              5.250000           6.200000           6.350000
# ...

# %%
#Descriptives for hco3
df = pd.DataFrame(hco3)
print('Descriptives hco3')
print(df.describe())
print('Medians hco3')
print(df.median())
# Out:
# Descriptives hco3
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean           26.109067          25.126232           25.697688
# std             4.268410           3.883325            3.817547
# min            10.900000          12.500000           14.000000
# 25%            23.100000          22.726355           23.200000
# 50%            25.643230          24.800000           25.200000
# 75%            28.701601          26.800000           27.775000
# max            43.100000          41.600000           45.600000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean            26.234140          26.822616          27.600731
# std              3.913968           3.929139           4.274759
# min              8.950000          12.700000          16.375000
# ...

# %%
#Descriptives for lac
df = pd.DataFrame(lac)
print('Descriptives lac')
print(df.describe())
print('Medians lac')
print(df.median())
# Out:
# Descriptives lac
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean            1.403966           1.397094            1.419143
# std             0.777128           0.695847            0.808216
# min             0.200000           0.300000            0.300000
# 25%             1.000000           1.000000            1.000000
# 50%             1.268142           1.277258            1.300000
# 75%             1.600000           1.600000            1.600000
# max            11.300000          11.300000           15.100000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean             1.531579           1.454045           1.476068
# std              1.057899           0.604725           0.593638
# min              0.500000           0.000000           0.300000
# ...

# %%
#Descriptives for spo2
df = pd.DataFrame(spo2)
print('Descriptives spo2')
print(df.describe())
print('Medians spo2')
print(df.median())
# Out:
# Descriptives spo2
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean           94.239935          94.789605           94.201823
# std             3.123616           2.999985            3.029810
# min            77.000000          84.000000           70.000000
# 25%            92.334988          92.949471           92.300417
# 50%            94.240778          95.000000           94.000000
# 75%            96.000000          97.000000           96.000000
# max           102.121107         100.636286          100.000000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean            93.940030          93.847677          93.692495
# std              3.007164           2.832180           3.126850
# min             79.000000          82.000000          70.000000
# ...

# %%
#Descriptives for pfr
df = pd.DataFrame(pfr)
print('Descriptives pfr')
print(df.describe())
print('Medians pfr')
print(df.median())
# Out:
# Descriptives pfr
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean           20.629188          21.917045           22.501526
# std            10.461404           9.748114            9.132257
# min             6.000000           6.195652            5.764706
# 25%            13.351977          15.108664           16.143143
# 50%            18.458462          20.106752           21.082955
# 75%            24.200000          26.346971           27.134921
# max            71.190000          68.571429           76.000000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean            22.250408          21.463406          22.016500
# std              8.673826           9.350688           9.689803
# min              6.550000           6.144578           6.666667
# ...

# %%
#Descriptives for paco2
df = pd.DataFrame(paco2)
print('Descriptives paco2')
print(df.describe())
print('Medians paco2')
print(df.median())
# Out:
# Descriptives paco2
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean            6.528176           6.502064            6.431533
# std             1.442005           1.566265            1.424440
# min             2.210000           2.210000            3.460000
# 25%             5.600000           5.442749            5.510000
# 50%             6.365121           6.300000            6.282541
# 75%             7.305777           7.319107            7.145855
# max            12.300000          13.800000           15.260000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean             6.635946           6.633754           6.810652
# std              1.477562           1.281731           1.537522
# min              3.800000           3.820000           3.160000
# ...

# %%
#Descriptives for ppress
df = pd.DataFrame(ppress)
print('Descriptives ppress')
print(df.describe())
print('Medians ppress')
print(df.median())
# Out:
# Descriptives ppress
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean           26.498671          26.345609           25.971994
# std             4.411718           5.149818            5.215191
# min            11.000000           6.000000            8.833333
# 25%            23.965095          23.000000           23.000000
# 50%            26.519219          27.000000           26.042644
# 75%            29.449033          30.000000           29.000000
# max            44.400000          42.800000           41.200000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean            25.686423          26.001249          26.130990
# std              5.458536           5.605760           6.065386
# min              8.500000           8.000000           6.000000
# ...

# %%
#Descriptives for ph
df = pd.DataFrame(ph)
print('Descriptives ph')
print(df.describe())
print('Medians ph')
print(df.median())
# Out:
# Descriptives ph
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean            7.360576           7.350218            7.361800
# std             0.077362           0.077264            0.070875
# min             6.920000           7.000000            7.025000
# 25%             7.320000           7.300000            7.320000
# 50%             7.361824           7.357500            7.370000
# 75%             7.409857           7.400000            7.405684
# max             7.599196           7.609000            7.600000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean             7.359024           7.363826           7.368486
# std              0.068634           0.069228           0.075569
# min              7.100000           7.038000           7.003000
# ...

# %%
#Descriptives for plat
df = pd.DataFrame(plat)
print('Descriptives plat')
print(df.describe())
print('Medians plat')
print(df.median())
# Out:
# Descriptives plat
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean          263.329488         261.999072          260.668655
# std           115.847874         109.116300          109.462542
# min             4.600000          27.500000            4.500000
# 25%           190.250000         195.456757          191.000000
# 50%           245.000000         244.394552          244.210257
# 75%           320.000000         319.375000          320.500000
# max          1265.000000        1059.500000          854.000000
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean           265.576853         270.485051         278.108567
# std            106.373539         111.822924         112.648804
# min             24.500000          20.000000          22.000000
# ...

# %%
#Descriptives for ventr
df = pd.DataFrame(ventr)
print('Descriptives ventr')
print(df.describe())
print('Medians ventr')
print(df.median())
# Out:
# Descriptives ventr
#        first_day_morning  first_day_evening  second_day_morning  \
# count         622.000000         622.000000          622.000000
# mean         1385.959484        1668.270289          616.394773
# std          2900.787139        3511.460024         1630.125596
# min         -8187.579965       -9240.396117        -3825.033689
# 25%             1.378589        -544.332844            1.305241
# 50%           916.619431        1664.977983            1.902777
# 75%          2871.443717        4033.737093            3.637175
# max         11401.046007       11401.046007         8036.623951
#
#        second_day_evening  third_day_morning  third_day_evening  \
# count          622.000000         622.000000         622.000000
# mean          1842.755658         679.260754        1947.393781
# std           3606.645531        1722.407201        3747.899038
# min          -9695.194112       -3949.596321       -9828.894723
# ...

# %%
#Descriptives for outcome not applciable

# %% [markdown]
# ## Histograms

# %% [markdown]
# **Preparing for Figure Generation**

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### CRP

# %%
# Load crp DataFrame
crp = pd.read_csv('/content/drive/MyDrive/CovidICU/CRP.csv')

# %% [markdown]
# Histograms

# %%
# Plot histograms for each column
crp.hist(figsize=(15, 15), bins=25, edgecolor='black', grid=False)

# Setting x and y labels for each subplot
plt.suptitle('Histograms of CRP Data', fontsize=16)  # Suptitle for the entire figure
for ax in plt.gcf().axes:
    ax.set_xlabel('CRP concentration in mg/dl')
    ax.set_ylabel('Counts')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit the suptitle
plt.show()

# %% [markdown]
# Boxplots

# %%
# Plot boxplots for each column
plt.figure(figsize=(30, 25))
box = crp.boxplot(grid=False)

# Set the axis labels and title
plt.xlabel('CRP concentration in mg/dl', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Distribution of CRP Concentration across ICU Patients', fontsize=18)

# Enable only horizontal grid lines
plt.grid(axis='y')

# Set y-axis ticks at intervals of 50
max_y = crp.max().max()  # Find the maximum y value in the dataset
plt.yticks(range(0, int(max_y) + 50, 50))

plt.show()

# %% [markdown]
# Violinplot

# %%
# Set figure size
sns.set(rc={"figure.figsize": (30, 25)})

# Create violin plot
ax = sns.violinplot(data=crp)

# Set axis labels and title
ax.set_xlabel('Time of Measurement', fontsize=14)
ax.set_ylabel('CRP concentration in mg/dl', fontsize=14)
ax.set_title('Distribution of CRP Concentration across ICU Patients', fontsize=18)

# Set y-axis ticks at intervals of 50
max_y = crp.max().max()  # Find the maximum y value in the dataset
plt.yticks(range(0, int(max_y) + 50, 50))

plt.show()

# %% [markdown]
# ### HCO3

# %%
# Load hco3 DataFrame
hco3 = pd.read_csv('/content/drive/MyDrive/CovidICU/HCO^-3.csv')

# %% [markdown]
# Histograms

# %%
# Plot histograms for each column
hco3.hist(figsize=(15, 15), bins=25, edgecolor='black', grid=False)

# Setting x and y labels for each subplot
plt.suptitle('Histograms of HCO^3 Data', fontsize=16)  # Suptitle for the entire figure
for ax in plt.gcf().axes:
    ax.set_xlabel('HCO^3 concentration in mg/dl')
    ax.set_ylabel('Counts')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit the suptitle
plt.show()

# %% [markdown]
# Boxplots

# %%
# Plot boxplots for each column
plt.figure(figsize=(30, 25))
box = hco3.boxplot(grid=False)

# Set the axis labels and title
plt.xlabel('HCO^3 concentration in mg/dl', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Distribution of HCO^3 Concentration across ICU Patients', fontsize=18)

# Enable only horizontal grid lines
plt.grid(axis='y')

# Calculate min and max y values with buffers
min_y = hco3.min().min() - 2
max_y = hco3.max().max() + 2

# Set y-axis ticks at intervals of 2
plt.yticks(range(int(min_y), int(max_y) + 2, 2))

plt.show()

# %% [markdown]
# Violinplot

# %%
# Set figure size
sns.set(rc={"figure.figsize": (30, 25)})

# Create violin plot
ax = sns.violinplot(data=hco3)

# Set axis labels and title
ax.set_xlabel('Time of Measurement', fontsize=14)
ax.set_ylabel('HCO^3 concentration in mg/dl', fontsize=14)
ax.set_title('Distribution of HCO^3 Concentration across ICU Patients', fontsize=18)

# Calculate min and max y values with buffers
min_y = hco3.min().min() - 2
max_y = hco3.max().max() + 2

# Set y-axis ticks at intervals of 2
plt.yticks(range(int(min_y), int(max_y) + 2, 2))

plt.show()

# %% [markdown]
# ### Lactate

# %%
# Load lac DataFrame
lac = pd.read_csv('/content/drive/MyDrive/CovidICU/Lactate.csv')

# %% [markdown]
# Histograms

# %%
# Plot histograms for each column
lac.hist(figsize=(15, 15), bins=35, edgecolor='black', grid=False)

# Setting x and y labels for each subplot
plt.suptitle('Histograms of Lactate Data', fontsize=16)  # Suptitle for the entire figure
for ax in plt.gcf().axes:
    ax.set_xlabel('Lactate concentration in mg/dl')
    ax.set_ylabel('Counts')

plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust layout to fit the suptitle
plt.show()

# %% [markdown]
# Boxplots

# %%
# Plot boxplots for each column
plt.figure(figsize=(30, 25))
box = lac.boxplot(grid=False)

# Set the axis labels and title
plt.xlabel('Lactate concentration in mg/dl', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Distribution of Lactate Concentration across ICU Patients', fontsize=18)

# Enable only horizontal grid lines
plt.grid(axis='y')

# Calculate min and max y values with buffers
min_y = lac.min().min()
max_y = lac.max().max() + 1

# Set y-axis ticks at intervals of 1
plt.yticks(range(int(min_y), int(max_y) + 1, 1))

plt.show()

# %% [markdown]
# Violinplots

# %%
# Set figure size
sns.set(rc={"figure.figsize": (30, 25)})

# Create violin plot
ax = sns.violinplot(data=lac)

# Set axis labels and title
ax.set_xlabel('Time of Measurement', fontsize=14)
ax.set_ylabel('Lactate concentration in mg/dl', fontsize=14)
ax.set_title('Distribution of Lactate Concentration across ICU Patients', fontsize=18)

# Calculate min and max y values with buffers
min_y = lac.min().min()
max_y = lac.max().max() + 1

# Set y-axis ticks at intervals of 1
plt.yticks(range(int(min_y), int(max_y) + 1, 1))

plt.show()

# %% [markdown]
# ### Oxygen Saturation (SpO2)

# %% [markdown]
# ### P-F-Ratio (pfr)

# %% [markdown]
# ### PaCO2

# %% [markdown]
# ### Peak Pressure

# %% [markdown]
# ### Platelet Count

# %% [markdown]
# ### Ventilatory Ratio

# %% [markdown]
# ### pH

# %% [markdown]
# ### Outcome

# %% [markdown]
# ## Principal Components Analysis

# %% [markdown]
# (20points)Perform a Principle Component Analysis on your chosen medical measurements by treating each column of the measurements as separate features. Plot the Cumulative Explained Variance of each PCA. Explain what you see.

# %% [markdown]
# Preparing for PCA

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# PCA – CRP

# %%
# Load the dataset
crp = pd.read_csv('/content/drive/MyDrive/CovidICU/CRP.csv')

# Standardize the data
features = crp.columns
scaler = StandardScaler()
scaled_crp = scaler.fit_transform(crp[features])

# Perform PCA
pca = PCA(n_components=len(features))
pca.fit(scaled_crp)

# Calculate the cumulative explained variance
cumulative_explained_variance = np.cumsum(pca.explained_variance_ratio_)

# Plot the cumulative explained variance
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(features) + 1), cumulative_explained_variance, marker='o', linestyle='--')
plt.title('Cumulative Explained Variance by PCA', fontsize=16)
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.grid()
plt.show()

# Print out the cumulative explained variance
print("Cumulative Explained Variance:")
for i, var in enumerate(cumulative_explained_variance):
    print(f"Principal Component {i+1}: {var:.2f}")

# Print the PCA component loadings
loadings = pd.DataFrame(pca.components_.T, columns=[f'PC{i+1}' for i in range(len(features))], index=features)
print("\nPCA Component Loadings:")
print(loadings)

# Create a heatmap for the PCA component loadings
plt.figure(figsize=(12, 8))
sns.heatmap(loadings, annot=True, cmap='coolwarm', center=0)
plt.title('PCA Component Loadings Heatmap', fontsize=16)
plt.xlabel('Principal Components')
plt.ylabel('Original Features')
plt.show()
# Out:
# Cumulative Explained Variance:
# Principal Component 1: 0.67
# Principal Component 2: 0.87
# Principal Component 3: 0.95
# Principal Component 4: 0.98
# Principal Component 5: 0.99
# Principal Component 6: 1.00
# Principal Component 7: 1.00
# Principal Component 8: 1.00
# Principal Component 9: 1.00
# Principal Component 10: 1.00
# Principal Component 11: 1.00
# Principal Component 12: 1.00
# Principal Component 13: 1.00
# Principal Component 14: 1.00
#
# PCA Component Loadings:
#                           PC1       PC2       PC3       PC4       PC5  \
# first_day_morning    0.215480 -0.380712  0.295187 -0.237726  0.362546
# first_day_evening    0.231711 -0.384285  0.262841 -0.170256  0.133447
# second_day_morning   0.238088 -0.371842  0.220026 -0.096654 -0.097998
# second_day_evening   0.276793 -0.305748  0.018413  0.155424 -0.280790
# third_day_morning    0.281682 -0.204877 -0.180617  0.383063 -0.425883
# third_day_evening    0.296197 -0.101746 -0.297792  0.295537 -0.031007
# ...

# %% [markdown]
# By examining the loadings, you can see which original features contribute most to each principal component. Large absolute values in the loadings indicate that the corresponding original feature has a strong influence on the principal component. Positive values indicate a positive correlation, while negative values indicate a negative correlation with the principal component.

# %% [markdown]
# # ***CDC Mortality Dataset Analysis***

# %% [markdown]
# ## General Overview

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ## Descriptive Statistics

# %% [markdown]
# ## Histograms
